# %% [markdown]
# Before running the file Upload all your data set on your goole drive in a zip format

# %%
#Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#To get the average frame count
import json
import glob
import numpy as np
import cv2
import copy
#change the path accordingly
video_files =  glob.glob('/content/drive/MyDrive/Major FINAL RUN/FINAL_ALTDATA/*.mp4')
#video_files1 =  glob.glob('/content/dfdc_train_part_0/*.mp4')
#video_files += video_files1
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-43a485743996> in <cell line: 12>()
#      11 frame_count = []
#      12 for video_file in video_files:
# ---> 13   cap = cv2.VideoCapture(video_file)
#      14   if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
#      15     video_files.remove(video_file)
#
# KeyboardInterrupt:

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path)
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image
# !pip3 install face_recognition
# !mkdir '/content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile'
import torch
import torchvision
from torchvision import transforms
from torch.utils.data import DataLoader
from torch.utils.data.dataset import Dataset
import os
import numpy as np
import cv2
import matplotlib.pyplot as plt
import face_recognition
from tqdm.autonotebook import tqdm
# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      #if(idx % 3 == 0):
      if(idx <= 100):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=9608e8c88d2393d3f6f94dea4fcca60f6892964f6d5924a9f3470140721f2131
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...
# mkdir: cannot create directory ‘/content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile’: File exists

# %%
create_face_videos(video_files,'/content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile')
# Out:
# No of videos already present  0
#   0%|          | 0/1899 [00:00<?, ?it/s]
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id55_0005.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id55_0000.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id54_0008.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id58_0001.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id57_0005.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id58_0004.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id58_0007.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id57_0000.mp4
# File Already exists:  /content/drive/MyDrive/Major FINAL RUN/only_Face_onlyfile/id53_id58_0008.mp4
# ...
